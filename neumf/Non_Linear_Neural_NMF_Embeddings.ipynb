# %% [markdown]
# ---
# ### Network Path and Training Architecture
# ---

# %% [markdown]
# 1. Given an input matrix X
#
# 2. Construct the network with sigmoid activations to get the output f(W, b|X)--> Encoder()
#
# 3. Decode the network to get ~f(X)
#
# 4. Obtain the reconstruction error Er = bce(X, ~f(X))
#
# 5. Compute the approximation error En = ||f(X) - UV||
#
# 6. Minimize over a*Er + En

# %% [markdown]
# ---
# ## Algorithm
# ---

# %% [markdown]
# 1. Input: X
# ---
# 2. Initialization:
#
# *   Pretrain W_, b_ via RBM
# *   Initialize U_, V_ with non-negative values
# ---
# 3. Using the pretrained weights, update the U_, V_ using the iNMF update rule. This will give a good first linear approximation of U and V.
# *   Loop for L times.
# ---
# 4. Introduce non-linearities:
#
#
# *   Using the pretrained weights from (2), construct the network f(W, b|X)
# *   Update U and V in the training loop
#
#
# *   Compute the approximation loss En
#
# *   Construct the decoder network ~f(W,b|X)
#
# *   Compute the reconstruction loss Er
#
# * Update W, b to minimize En + ss(Er)

# %%
## import libraries
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
## import sklearn modules
from sklearn.model_selection import train_test_split
## import keras models, layers and optimizers
import tensorflow as tf
import keras
from keras.layers import LeakyReLU
import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Embedding, Flatten, Dense, Dropout, concatenate, multiply, Input, Dot, Masking
from keras.optimizers import Adam
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from keras.constraints import Constraint
# Out:
# Using TensorFlow backend.

# %%
data1 = pd.read_csv("https://raw.githubusercontent.com/Mcpaeis/Independent-Study/master/Data/xns0-inmf-paper.csv", sep=",", header=0)
# https://sixtusdakurah.com/projects/liger/stim_sparse_dfp.csv
data2 = pd.read_csv("https://raw.githubusercontent.com/Mcpaeis/Independent-Study/master/Data/xns1-inmf-paper.csv", sep=",", header=0)
# datan = pd.read_csv("https://raw.githubusercontent.com/Mcpaeis/Independent-Study/master/Data/xns0-inmf-paper.csv")
print("Shape of data 1:", data1.shape)
#data2 = data1.iloc[1:500, ]
print("Shape of data 2:", data2.shape)
#data3 = pd.concat([data1, data2])
#print("Shape of data 3:", data3.shape)
#print("Shape of data n:", datan.shape)
# Out:
# Shape of data 1: (1000, 401)
# Shape of data 2: (1000, 601)
#    Unnamed: 0         0         1  ...       397       398       399
# 0           0  0.008902  2.534829  ...  1.494660  2.175169  1.404495
# 1           1  0.003033  0.008003  ...  1.777076  0.288062  0.838839
# 2           2  1.441777  0.003417  ...  0.527838  0.090281  1.310410
# 3           3  0.001075  0.006045  ...  2.782726  0.338218  1.314088
# 4           4  1.263001  0.001746  ...  0.199667  0.007687  3.280799
#
# [5 rows x 401 columns]

# %%
# get the extracted columns
x1_genes = data1['Unnamed: 0']
print(x1_genes)
x2_genes = data2['Unnamed: 0']
print(x2_genes)
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Name: Unnamed: 0, Length: 1000, dtype: int64
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Name: Unnamed: 0, Length: 1000, dtype: int64

# %%
data1.head()
# Out:
#    Unnamed: 0         0         1  ...       397       398       399
# 0           0  0.008902  2.534829  ...  1.494660  2.175169  1.404495
# 1           1  0.003033  0.008003  ...  1.777076  0.288062  0.838839
# 2           2  1.441777  0.003417  ...  0.527838  0.090281  1.310410
# 3           3  0.001075  0.006045  ...  2.782726  0.338218  1.314088
# 4           4  1.263001  0.001746  ...  0.199667  0.007687  3.280799
#
# [5 rows x 401 columns]

# %%
# melt data
X1 = pd.melt(data1, id_vars=['Unnamed: 0'], var_name='cell', value_name='val')
X1.rename(columns = {'Unnamed: 0':'gene'}, inplace = True)
#X1 = X1.loc[X1['gene'].isin(x2_genes)] ## select genes common to X1 and X2
X1['gene'] = X1['gene'].astype('category')
X1['gene'] = X1['gene'].cat.codes
X1['cell'] = X1['cell'].astype('category')
X1['cell'] = X1['cell'].cat.codes
X1.head()
# Out:
#    gene  cell       val
# 0     0     0  0.008902
# 1     1     0  0.003033
# 2     2     0  1.441777
# 3     3     0  0.001075
# 4     4     0  1.263001

# %%
# melt data
X2 = pd.melt(data2, id_vars=['Unnamed: 0'], var_name='cell', value_name='val')
X2.rename(columns = {'Unnamed: 0':'gene'}, inplace = True)
X2['gene'] = X2['gene'].astype('category')
X2['gene'] = X2['gene'].cat.codes
X2['cell'] = X2['cell'].astype('category')
X2['cell'] = X2['cell'].cat.codes
X2.head()
# Out:
#    gene  cell       val
# 0     0     0  0.004465
# 1     1     0  0.476762
# 2     2     0  0.000520
# 3     3     0  0.164034
# 4     4     0  0.006510

# %%
n_rows1 = len((X1.cell).unique())
n_cols1 = len((X1.gene).unique())
print(n_rows1)
print(n_cols1)
n_rows2 = len((X2.cell).unique())
n_cols2 = len((X2.gene).unique())
print(n_rows2)
print(n_cols2)
# print(n_rows_)
# print(n_cols_)
# Out:
# 400
# 1000
# 600
# 1000

# %%
## Load pre-trained embeddings
W_Embedding = pd.read_csv("https://raw.githubusercontent.com/Mcpaeis/Independent-Study/master/Data/W-Embedding.csv", sep=",", header=None)
H1_Embedding = pd.read_csv("https://raw.githubusercontent.com/Mcpaeis/Independent-Study/master/Data/H1-Embedding.csv", sep=",", header=None)
H2_Embedding = pd.read_csv("https://raw.githubusercontent.com/Mcpaeis/Independent-Study/master/Data/H2-Embedding.csv", sep=",", header=None)
print("W_Embedding shape: ", W_Embedding.shape)
print("H1_Embedding shape: ", H1_Embedding.shape)
print("H2_Embedding shape: ", H2_Embedding.shape)
# Out:
# W_Embedding shape:  (1001, 20)
# H1_Embedding shape:  (401, 20)
# H2_Embedding shape:  (601, 20)

# %%
W_Embedding.head()
# Out:
#          0         1         2   ...        17        18        19
# 0  0.000220  0.000684  0.476492  ...  0.000325  0.000295  0.495727
# 1  0.137011  0.510143  0.029325  ...  0.017845  0.292212  0.219307
# 2  0.094078  0.570294  0.058597  ...  0.117011  0.196096  0.011353
# 3  0.084954  0.260520  0.119241  ...  0.046008  0.078756  0.001652
# 4  0.007898  0.485009  0.134871  ...  0.159255  0.018271  0.106576
#
# [5 rows x 20 columns]

# %%
## create keras model
dim_embeddings = 20

## rows
row_input = Input(shape=[1], name='X1-Row')
masked_row_input = Masking(mask_value=-10)(row_input)
row_embedding = Embedding(n_rows1 + 1, dim_embeddings, weights = [H1_Embedding],
                          trainable = True, name="H1-Embedding",
                          embeddings_constraint=tf.keras.constraints.NonNeg())(masked_row_input)
#row_bias = Embedding(n_rows1 + 1, bias, name="Row-Bias")(row_input)

## cols
col_input = Input(shape=[1],name='X2-Row')
masked_col_input = Masking(mask_value=-10)(col_input)
col_embedding = Embedding(n_rows2 + 1, dim_embeddings, name="H2-Embedding",
                          weights = [H2_Embedding],
                          trainable = True,
                          embeddings_constraint=tf.keras.constraints.NonNeg())(masked_col_input)
#col_bias = Embedding(n_rows2 + 1, bias, name="Col-Bias")(col_input)

## cols
rc_input = Input(shape=[1], name='RC-Column')
masked_rc_input = Masking(mask_value=-10)(rc_input)
# cols 1 or cols 2 will do
rc_embedding = Embedding(n_cols1 + 1, dim_embeddings, name="W-Embedding",
                         weights = [W_Embedding],
                          trainable = True,
                         embeddings_constraint=tf.keras.constraints.NonNeg())(masked_rc_input)
rc_embedding_t = keras.layers.Permute((2, 1))(rc_embedding)
#rc_bias = Embedding(n_cols_ + 1, bias, name="RC-Bias")(rc_input)

## matrix product
matrix_product = Dot(axes=(1, 2))([row_embedding, rc_embedding_t]) #([row_embedding, rc_embedding_t])
matrix_product = Dropout(0.2)(matrix_product)
matrix_product_ = Dot(axes=(1, 2))([col_embedding, rc_embedding_t])
matrix_product_ = Dropout(0.2)(matrix_product_)

#matrix_product_gen = multiply([row_embedding, col_embedding, rc_embedding])

## add bias terms
# input_terms = concatenate([matrix_product, rc_bias, row_bias])
input_terms = Flatten()(matrix_product)
# input_terms_ = concatenate([matrix_product, rc_bias, col_bias])
input_terms_ = Flatten()(matrix_product_)

## Construct the linear update rule.

## add dense layers
dense_1 = Dense(150, activation='relu', name = "Dense1")(input_terms)
dense_1 = Dropout(0.2)(dense_1)
dense_2 = Dense(120, activation="relu", name = "Dense2")(dense_1)
dense_2 = Dropout(0.2)(dense_2)
dense_3 = Dense(90, activation="relu", name = "Dense3")(dense_2)
dense_3 = Dropout(0.2)(dense_3)
dense_4 = Dense(60, activation="relu", name = "Dense4")(dense_3)
dense_4 = Dropout(0.2)(dense_4)
dense_5 = Dense(20, activation="relu", name = "Dense5")(dense_4)
dense_5 = Dropout(0.2)(dense_5)
result = Dense(1, activation='softmax', name='X1-Output')(dense_5)
# add dense layers
dense_1_ = Dense(150, activation="relu", name = "Dense1_")(input_terms_)
dense_1_ = Dropout(0.2)(dense_1_)
dense_2_ = Dense(120, activation="relu", name = "Dense2_")(dense_1_)
dense_2_ = Dropout(0.2)(dense_2_)
dense_3_ = Dense(90, activation="relu", name = "Dense3_")(dense_2_)
dense_3_ = Dropout(0.2)(dense_3_)
dense_4_ = Dense(60, activation="relu", name = "Dense4_")(dense_3_)
dense_4_ = Dropout(0.2)(dense_4_)
dense_5_ = Dense(20, activation="relu", name = "Dense5_")(dense_4_)
dense_5_ = Dropout(0.2)(dense_5_)
result_ = Dense(1, activation='softmax', name='X2-Output')(dense_5_)



## define model with 2 inputs and 1 output
model_mf = Model(inputs=[row_input, col_input, rc_input], outputs=[result, result_])

## show model summary
model_mf.summary()

print(model_mf.inputs)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# RC-Column (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# X1-Row (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# masking_27 (Masking)            (None, 1)            0           RC-Column[0][0]
# __________________________________________________________________________________________________
# X2-Row (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# masking_25 (Masking)            (None, 1)            0           X1-Row[0][0]
# __________________________________________________________________________________________________
# W-Embedding (Embedding)         (None, 1, 20)        20020       masking_27[0][0]
# __________________________________________________________________________________________________
# masking_26 (Masking)            (None, 1)            0           X2-Row[0][0]
# __________________________________________________________________________________________________
# H1-Embedding (Embedding)        (None, 1, 20)        8020        masking_25[0][0]
# __________________________________________________________________________________________________
# permute_9 (Permute)             (None, 20, 1)        0           W-Embedding[0][0]
# __________________________________________________________________________________________________
# H2-Embedding (Embedding)        (None, 1, 20)        12020       masking_26[0][0]
# __________________________________________________________________________________________________
# dot_17 (Dot)                    (None, 20, 20)       0           H1-Embedding[0][0]
#                                                                  permute_9[0][0]
# __________________________________________________________________________________________________
# dot_18 (Dot)                    (None, 20, 20)       0           H2-Embedding[0][0]
#                                                                  permute_9[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 20, 20)       0           dot_17[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 20, 20)       0           dot_18[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 400)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 400)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 150)          60150       flatten_17[0][0]
# __________________________________________________________________________________________________
# Dense1_ (Dense)                 (None, 150)          60150       flatten_18[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 150)          0           Dense1[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 150)          0           Dense1_[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 120)          18120       dropout_39[0][0]
# __________________________________________________________________________________________________
# Dense2_ (Dense)                 (None, 120)          18120       dropout_44[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 120)          0           Dense2[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 120)          0           Dense2_[0][0]
# __________________________________________________________________________________________________
# Dense3 (Dense)                  (None, 90)           10890       dropout_40[0][0]
# __________________________________________________________________________________________________
# Dense3_ (Dense)                 (None, 90)           10890       dropout_45[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 90)           0           Dense3[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 90)           0           Dense3_[0][0]
# __________________________________________________________________________________________________
# Dense4 (Dense)                  (None, 60)           5460        dropout_41[0][0]
# __________________________________________________________________________________________________
# Dense4_ (Dense)                 (None, 60)           5460        dropout_46[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 60)           0           Dense4[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 60)           0           Dense4_[0][0]
# __________________________________________________________________________________________________
# Dense5 (Dense)                  (None, 20)           1220        dropout_42[0][0]
# __________________________________________________________________________________________________
# Dense5_ (Dense)                 (None, 20)           1220        dropout_47[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 20)           0           Dense5[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 20)           0           Dense5_[0][0]
# __________________________________________________________________________________________________
# X1-Output (Dense)               (None, 1)            21          dropout_43[0][0]
# __________________________________________________________________________________________________
# X2-Output (Dense)               (None, 1)            21          dropout_48[0][0]
# ==================================================================================================
# Total params: 231,782
# Trainable params: 231,782
# Non-trainable params: 0
# __________________________________________________________________________________________________
# [<tf.Tensor 'X1-Row_8:0' shape=(None, 1) dtype=float32>, <tf.Tensor 'X2-Row_8:0' shape=(None, 1) dtype=float32>, <tf.Tensor 'RC-Column_8:0' shape=(None, 1) dtype=float32>]

# %%
keras.utils.plot_model(model_mf, "multi_input_and_output_model.png", show_shapes=True)

# %%
## Get indexes and inputs
special_value = -10.0
r = (np.array(X1['cell']).reshape(-1, 1))
print("r shape: ",r.shape[0])
c = (np.array(X2['cell']).reshape(-1, 1))
print("c shape: ",c.shape)
rc = (np.array(X1['gene']).reshape(-1, 1))
print("rc shape: ", rc.shape)
max_len = max(r.shape[0], c.shape[0], rc.shape[0])
print("max len: ", max_len)
padded_sequence = tf.keras.preprocessing.sequence.pad_sequences([r, c, rc], value=-10, padding="post")
rp = padded_sequence[0]
print("rp shape: ",rp.shape)
cp = padded_sequence[1]
print("cp shape: ",cp.shape)
rcp = padded_sequence[2]
print("rcp shape: ",rcp.shape)
padded_target = tf.keras.preprocessing.sequence.pad_sequences([X1['val'], X2['val']], value=-10, padding="post")
val1 = padded_target[0]
val2 = padded_target[1]
# Out:
# r shape:  400000
# c shape:  (600000, 1)
# rc shape:  (400000, 1)
# max len:  600000
# rp shape:  (600000, 1)
# cp shape:  (600000, 1)
# rcp shape:  (600000, 1)

# %%
## specify learning rate (or use the default)
opt_adam = Adam(lr = 0.002)

## compile model
model_mf.compile(optimizer = opt_adam, loss = ['mse', 'mse'], metrics = ['mean_squared_error'])

## fit model
history_mf = model_mf.fit({"X1-Row": rp, "X2-Row": cp, "RC-Column": rcp},
                          {"X1-Output": val1, "X2-Output": val2},
                          batch_size = 256,
                          validation_split = 0.3,
                          epochs = 100,
                          verbose = 1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 420000 samples, validate on 180000 samples
# Epoch 1/100
# 420000/420000 [==============================] - 19s 46us/step - loss: 7.4884 - X1-Output_loss: 6.5995 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 2/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 3/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6002 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 4/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6006 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 5/100
# 420000/420000 [==============================] - 19s 46us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 6/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5989 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 7/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 8/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5987 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 9/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 10/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 11/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 12/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 13/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 14/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 15/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 16/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6006 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 17/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 18/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 19/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6003 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 20/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 21/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 22/100
# 420000/420000 [==============================] - 19s 46us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 23/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6002 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 24/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 25/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 26/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 27/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5990 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 28/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 29/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 30/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5998 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 31/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5991 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 32/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5989 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 33/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 34/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 35/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5989 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 36/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 37/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 38/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6006 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 39/100
# 420000/420000 [==============================] - 19s 45us/step - loss: 7.4884 - X1-Output_loss: 6.6006 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 40/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 41/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 42/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 43/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 44/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 45/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5989 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 46/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 47/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6009 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 48/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 49/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6002 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 50/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 51/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5991 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 52/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 53/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 54/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 55/100
# 420000/420000 [==============================] - 19s 46us/step - loss: 7.4884 - X1-Output_loss: 6.6006 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 56/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6011 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 57/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 58/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6004 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 59/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 60/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 61/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 62/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5998 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 63/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 64/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6004 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 65/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 66/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 67/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6004 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 68/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5989 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 69/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 70/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 71/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 72/100
# 420000/420000 [==============================] - 20s 47us/step - loss: 7.4884 - X1-Output_loss: 6.6003 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 73/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5990 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 74/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 75/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.6002 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 76/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5990 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 77/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 78/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 79/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5990 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 80/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5994 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 81/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 82/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6004 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 83/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5999 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 84/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 85/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 86/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 87/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5996 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 88/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 89/100
# 420000/420000 [==============================] - 19s 46us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 90/100
# 420000/420000 [==============================] - 19s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5992 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 91/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 92/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 93/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 94/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 95/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 96/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.6004 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 97/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.5997 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 98/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.5985 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 99/100
# 420000/420000 [==============================] - 18s 43us/step - loss: 7.4884 - X1-Output_loss: 6.6001 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683
# Epoch 100/100
# 420000/420000 [==============================] - 18s 44us/step - loss: 7.4884 - X1-Output_loss: 6.6003 - X2-Output_loss: 0.8887 - X1-Output_mean_squared_error: 6.5997 - X2-Output_mean_squared_error: 0.8887 - val_loss: 121.8683 - val_X1-Output_loss: 121.0000 - val_X2-Output_loss: 0.8684 - val_X1-Output_mean_squared_error: 121.0000 - val_X2-Output_mean_squared_error: 0.8683

# %%
# print out the layers
index = 0
for lay in model_mf.layers:
  print(lay.name, 'at index: ', index)
  index+=1
# Out:
# RC-Column at index:  0
# X1-Row at index:  1
# masking_27 at index:  2
# X2-Row at index:  3
# masking_25 at index:  4
# W-Embedding at index:  5
# masking_26 at index:  6
# H1-Embedding at index:  7
# permute_9 at index:  8
# H2-Embedding at index:  9
# dot_17 at index:  10
# dot_18 at index:  11
# dropout_37 at index:  12
# dropout_38 at index:  13
# flatten_17 at index:  14
# flatten_18 at index:  15
# Dense1 at index:  16
# Dense1_ at index:  17
# dropout_39 at index:  18
# dropout_44 at index:  19
# Dense2 at index:  20
# Dense2_ at index:  21
# dropout_40 at index:  22
# dropout_45 at index:  23
# Dense3 at index:  24
# Dense3_ at index:  25
# dropout_41 at index:  26
# dropout_46 at index:  27
# Dense4 at index:  28
# Dense4_ at index:  29
# dropout_42 at index:  30
# dropout_47 at index:  31
# Dense5 at index:  32
# Dense5_ at index:  33
# dropout_43 at index:  34
# dropout_48 at index:  35
# X1-Output at index:  36
# X2-Output at index:  37

# %%
## get weights of embedding matrix
W = model_mf.layers[5].get_weights()[0]
H1 = model_mf.layers[7].get_weights()[0]
H2 = model_mf.layers[9].get_weights()[0]
print("W shape: ", W.shape)
print("H1 shape: ", H1.shape)
print("H2 shape: ", H2.shape)
# Out:
# W shape:  (1001, 20)
# H1 shape:  (401, 20)
# H2 shape:  (601, 20)

# %%
(pd.DataFrame(W)).head()
# Out:
#          0         1         2   ...        17        18        19
# 0  0.000220  0.000684  0.476492  ...  0.000325  0.000295  0.495727
# 1  0.137011  0.510143  0.029325  ...  0.017845  0.292212  0.219307
# 2  0.094078  0.570294  0.058597  ...  0.117011  0.196096  0.011353
# 3  0.084954  0.260520  0.119241  ...  0.046008  0.078756  0.001652
# 4  0.007898  0.485009  0.134871  ...  0.159255  0.018271  0.106576
#
# [5 rows x 20 columns]

# %%
def plot3D(df, title):
  my_dpi=96
  plt.figure(figsize=(480/my_dpi, 480/my_dpi), dpi=my_dpi)
  pca = PCA(n_components=3)
  df = pd.DataFrame(df)
  pca.fit(df)
  # Store results of PCA in a data frame
  result=pd.DataFrame(pca.transform(df), columns=['PCA%i' % i for i in range(3)], index=df.index)

  # Plot initialisation
  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')
  ax.scatter(result['PCA0'], result['PCA1'], result['PCA2'], s=60)

  # label the axes
  ax.set_title(title)
  plt.show()

# %%
d1 = data1.drop(columns=['Unnamed: 0'])
d2 = data2.drop(columns=['Unnamed: 0'])
plot3D(d1, "Data 1")
plot3D(d2, "Data 2")
plot3D(pd.DataFrame(W), "W")
